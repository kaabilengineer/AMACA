# %%
from glob import glob
import pandas as pd
from pygame import mixer
import time

def songs():
    all_songs = pd.DataFrame(glob('E:Songs\*'))
    all_songs.columns = ['Songs']
 
    file = pd.DataFrame(glob('E:Songs\*'))
    file.columns = ['Songs']

    speak("Which song to play?")
    user_input = input("Which song to play? ") #song name input by user
    inp = user_input
    user_input = user_input.replace(" ", "_")
    song =  user_input + '.mp3'
    
    mixer.init()
    mixer.music.load('E:Songs\\'+song)
    mixer.music.play()
    time.sleep(15)
    mixer.music.stop()
songs()
# Out:
# Which song to play? Youngblood

# %%
#!pip install opencv-python
import cv2
import pyttsx3

engine=pyttsx3.init('sapi5')
voices=engine.getProperty('voices')
engine.setProperty('voice',voices[1].id)
chrome_path="C:\Program Files (x86)\Google\Chrome\Application\chrome.exe"

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def play_video():
    
    speak("Which video to play?")
    video = input('Which video to play?')
    name = video
    video = video.replace(" ", "_")
    video = video + '.mp4'
    path = 'E:Videos\\'+video
    
    cap = cv2.VideoCapture(path)
    print("Playing "+name)
    speak("Playing"+name)
    while(cap.isOpened()):
        ret,frame = cap.read()
        frame = cv2.resize(frame,(1200, 700))
        cv2.imshow('video', frame)
        if cv2.waitKey(10) & 0xFF == ord(" "):
            break
            
    cap.release()
    cv2.destroyAllWindows()
    
play_video()

# %%
from  import mixer
import time

def animal_sounds():
    mixer.init()
    # path = "E:animal_sounds\\"
    if 'What sound does dog makes' in query:
        mixer.music.load(file= 'dog.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'dog sound' in query:
        mixer.music.load(file= 'dog.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does cat makes' in query:
        mixer.music.load(file= 'cat.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'cat sound' in query:
        mixer.music.load(file= 'cat.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does cow makes' in query:
        mixer.music.load(file= 'cow.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'cow sound' in query:
        mixer.music.load(file= 'cow.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does sheep makes' in query:
        mixer.music.load(file= 'sheep.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'sheep sound' in query:
        mixer.music.load(file= 'sheep.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does whale makes' in query:
        mixer.music.load(file= 'whale.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'whale sound' in query:
        mixer.music.load(file= 'whale.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does goat makes' in query:
        mixer.music.load(file= 'goat.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'goat sound' in query:
        mixer.music.load(file= 'goat.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does geese makes' in query:
        mixer.music.load(file= 'geese.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'geese sound' in query:
        mixer.music.load(file= 'geese.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does duck makes' in query:
        mixer.music.load(file= 'duck.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'duck sound' in query:
        mixer.music.load(file= 'duck.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does horse makes' in query:
        mixer.music.load(file= 'horse.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'horse sound' in query:
        mixer.music.load(file= 'horse.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does parrot makes' in query:
        mixer.music.load(file= 'parrot.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'parrot sound' in query:
        mixer.music.load(file= 'parrot.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does owl makes' in query:
        mixer.music.load(file= 'owl.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'owl sound' in query:
        mixer.music.load(file= 'owl.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does canary makes' in query:
        mixer.music.load(file= 'canary.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'canary sound' in query:
        mixer.music.load(file= 'canary.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does crow makes' in query:
        mixer.music.load(file= 'crow.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'crow sound' in query:
        mixer.music.load(file= 'crow.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does donkey makes' in query:
        mixer.music.load(file= 'donkey.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'donkey sound' in query:
        mixer.music.load(file= 'donkey.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does tiger makes' in query:
        mixer.music.load(file= 'tiger.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'tiger sound' in query:
        mixer.music.load(file= 'tiger.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does lion makes' in query:
        mixer.music.load(file= 'lion.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'lion sound' in query:
        mixer.music.load(file= 'lion.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does elephant makes' in query:
        mixer.music.load(file= 'elephant.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'elephant sound' in query:
        mixer.music.load(file= 'elephant.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does panda makes' in query:
        mixer.music.load(file= 'panda.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'panda sound' in query:
        mixer.music.load(file= 'panda.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does nightingale makes' in query:
        mixer.music.load(file= 'nightingale.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'nightingale sound' in query:
        mixer.music.load(file= 'nightingale.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    elif 'What sound does peacock makes' in query:
        mixer.music.load(file= 'peacock.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop()
    elif 'peacock sound' in query:
        mixer.music.load(file= 'peacock.mp3')
        mixer.music.play()
        time.sleep(5)
        mixer.music.stop
    
animal_sounds()
